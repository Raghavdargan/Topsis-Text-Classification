# %% [markdown]
# ## Topsis Text Classification
# Name: Raghav Dargan
# Roll No. 102103042

# %%
pip install Topsis-Raghav-102103042
# Out:
# ...
#   Obtaining dependency information for Topsis-Raghav-102103042 from https://files.pythonhosted.org/packages/f4/bf/eb2d8635b6b1f009c8bad38b250453e099c40cc28c471f79ffe6ca54f241/Topsis_Raghav_102103042-1.1.2-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !topsis assign_2.csv "1,1,1" "+,+,+" output.csv
# Out:
# TOPSIS analysis completed. Result saved to {result_file}

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# %%
FinalAnswer = pd.read_csv('output.csv')

# %%
FinalAnswer
# Out:
#                               MODEL  ACCURACY      AP      F1  Topsis Score  \
# 0             jamesgpt1/sf_model_e5    70.851  33.779  64.970      1.000000
# 1            BAAI/bge-large-en-v1.5    75.851  38.566  69.694      0.590704
# 2  Cohere/Cohere-embed-english-v3.0    81.299  46.182  75.477      0.000000
# 3   intfloat/e5-mistral-7b-instruct    78.687  41.715  72.372      0.335994
# 4            WhereIsAI/UAE-Large-V1    75.552  38.264  69.410      0.615972
#
#    Rank
# 0   1.0
# 1   3.0
# 2   5.0
# 3   4.0
# 4   2.0

# %%
# Assuming your DataFrame is named 'FinalAnswer'
model_names = FinalAnswer['MODEL']
topsis_scores = FinalAnswer['Topsis Score']

# Plotting the bar graph
plt.figure(figsize=(5,5))
plt.bar(model_names, topsis_scores, color='red')
plt.xlabel('Model Name')
plt.ylabel('Topsis Score')
plt.title('Topsis Score evaluation for different text classification models (Done by Raghav Dargan)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
